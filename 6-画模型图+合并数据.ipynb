# %%
from keras.optimizers import Adam
# Compile the model
# Create the RNN model
import tensorflow as tf
from keras.utils.vis_utils import plot_model

model = tf.keras.Sequential([
tf.keras.layers.LSTM(64, return_sequences=True, input_shape=(1,30)),
tf.keras.layers.Dropout(0.2),
tf.keras.layers.LSTM(32),
tf.keras.layers.Dropout(0.2),
tf.keras.layers.Dense(1)
])
model.compile(optimizer=Adam(0.0009), loss='mse')
 # Train the model

plot_model(model, to_file='model.png', show_shapes=True, show_layer_names=True)

# %%
import pandas as pd
 # 读取文件
file1 = pd.read_csv("predictions-有-1-1.csv")
file2 = pd.read_csv("predictions-有-2-1.csv")
file3 = pd.read_csv("predictions-有-3-1.csv")
file5 = pd.read_csv("predictions-有-5-1.csv")
file4 = pd.read_csv("predictions-有-4-1.csv")
file6 = pd.read_csv("predictions-有-6-1.csv")
file7 = pd.read_csv("predictions-无-item_code.csv")
file8 = pd.read_csv("predictions-无-sales_region_code.csv")
 # 合并文件
merged_file = pd.concat([file1, file2, file3, file4, file5, file6, file7, file8])
 # 保存合并后的文件
merged_file.to_csv("merged_file.csv", index=False)
